# %% [markdown]
# <a href="https://colab.research.google.com/github/nvnsudharsan/ARCO_data_download/blob/main/ARCO_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q xarray zarr gcsfs
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.4/205.4 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 44.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.7/53.7 kB 3.0 MB/s eta 0:00:00

# %%
import xarray as xr

# %%
ds = xr.open_zarr(
    'gs://gcp-public-data-arco-era5/ar/full_37-1h-0p25deg-chunk-1.zarr-v3',
    chunks=None,
    storage_options={"token": "anon"}
)
ds = ds.sel(time=slice(ds.attrs['valid_time_start'], ds.attrs['valid_time_stop']))

# %%
ssrd_sa = ds["surface_solar_radiation_downwards"].sel(
    time=slice("1995-01-01", "2014-12-31"),
    latitude=slice(25, 19),  # N to S
    longitude=slice(67, 76)  # W to E
)

# %%
#ssrd_wm2 = ssrd_sa / 3600

# %%
ssrd_sa
# Out:
# <xarray.DataArray 'surface_solar_radiation_downwards' (time: 175320,
#                                                        latitude: 25,
#                                                        longitude: 37)> Size: 649MB
# [162171000 values with dtype=float32]
# Coordinates:
#   * latitude   (latitude) float32 100B 25.0 24.75 24.5 24.25 ... 19.5 19.25 19.0
#   * longitude  (longitude) float32 148B 67.0 67.25 67.5 ... 75.5 75.75 76.0
#   * time       (time) datetime64[ns] 1MB 1995-01-01 ... 2014-12-31T23:00:00
# Attributes:
#     long_name:      Surface solar radiation downwards
#     short_name:     ssrd
#     standard_name:  surface_downwelling_shortwave_flux_in_air
#     units:          J m**-2
